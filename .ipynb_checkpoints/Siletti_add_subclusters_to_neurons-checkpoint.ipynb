# %%
# %%bash
#
# # convert Silletti in ABC to cas
# cas abc2cas --catset ABC_source/cluster_annotation_term_set.csv --cat ABC_source/cluster_annotation_term.csv --output intermediatte_files/Siletti_from_abc.json
# Out:
# /Users/aa37/Documents/GitHub/siletti_hacking/venv/lib/python3.9/site-packages/pysolr.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import DistributionNotFound, get_distribution, parse_version

# %%
import json

#  Open files

with open('./intermediatte_files/Siletti_from_abc.json', 'r') as f:
    Siletti_abc_cas = json.loads(f.read())

with open('./cas_source/CS202210140_non_neuronal.json', 'r') as f:
    nn = json.loads(f.read())
with open('./cas_source/CS202210140_neurons.json', 'r') as f:
    neurons = json.loads(f.read())

#Generate lookups for accessions for nn and neuron clusters respectively
neuron_clusters = { a['cell_set_accession'] for a in neurons['annotations'] 
                    if a['labelset'] == 'Cluster'}
nn_clusters = { a['cell_set_accession'] for a in nn['annotations'] 
                    if a['labelset'] == 'Cluster'}

# Make lists of subclusters from ABC that have a parent cluster in nn & neurons respectively
nn_subclusters = [a for a in Siletti_abc_cas['annotations']
                  if (a['labelset'] == 'subcluster') 
                  and (a['parent_cell_set_accession'] in nn_clusters)]
neuron_subclusters = [a for a in Siletti_abc_cas['annotations']
                  if (a['labelset'] == 'subcluster') 
                  and (a['parent_cell_set_accession'] in neuron_clusters)]

# Merge in subclusters

nn['annotations'].extend(nn_subclusters)
neurons['annotations'].extend(neuron_subclusters)

# %%
#Commenting as depends on path to anndata file - not stored in repo
#%%bash
# Generate file of CAS files from subclusters in Siletti anndata files
#cas anndata2cas --anndata Siletti_all_non_neuronal_cells.h5ad --labelsets subcluster_id --output intermediatte_files/Siletti_subclusters_from_anndata_cas.json

# %%
# Generate lookup for subcluster cell_ids, keyed on subclusters_id

# Open files
import json
with open('./intermediatte_files/Siletti_subclusters_from_anndata_cas.json', 'r') as f:
    Siletti_subclusters_from_ad = json.loads(f.read())

subcluster_cell_id_lookup = { a['cell_label'] : a['cell_ids'] for a in Siletti_subclusters_from_ad['annotations']}

# %%
# Check number of matches on both sides
len(subcluster_cell_id_lookup.keys())
# Out:
# 297

# %%
len(Siletti_subclusters_from_ad['annotations'])
# Out:
# 297

# %%
len(neuron_subclusters)
# Out:
# 3016

# %%
neuron_subclusters
# Out:
# [{'labelset': 'subcluster',
#   'cell_label': 'URL_297_0',
#   'cell_set_accession': 'CS202210140_494',
#   'parent_cell_set_accession': 'CS202210140_298'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_308_1',
#   'cell_set_accession': 'CS202210140_495',
#   'parent_cell_set_accession': 'CS202210140_309'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_308_2',
#   'cell_set_accession': 'CS202210140_496',
#   'parent_cell_set_accession': 'CS202210140_309'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_308_3',
#   'cell_set_accession': 'CS202210140_497',
#   'parent_cell_set_accession': 'CS202210140_309'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_308_4',
#   'cell_set_accession': 'CS202210140_498',
#   'parent_cell_set_accession': 'CS202210140_309'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_308_5',
#   'cell_set_accession': 'CS202210140_499',
#   'parent_cell_set_accession': 'CS202210140_309'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_309_6',
#   'cell_set_accession': 'CS202210140_500',
#   'parent_cell_set_accession': 'CS202210140_310'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_309_7',
#   'cell_set_accession': 'CS202210140_501',
#   'parent_cell_set_accession': 'CS202210140_310'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_309_8',
#   'cell_set_accession': 'CS202210140_502',
#   'parent_cell_set_accession': 'CS202210140_310'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_310_9',
#   'cell_set_accession': 'CS202210140_503',
#   'parent_cell_set_accession': 'CS202210140_311'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_311_10',
#   'cell_set_accession': 'CS202210140_504',
#   'parent_cell_set_accession': 'CS202210140_312'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_311_11',
#   'cell_set_accession': 'CS202210140_505',
#   'parent_cell_set_accession': 'CS202210140_312'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_311_12',
#   'cell_set_accession': 'CS202210140_506',
#   'parent_cell_set_accession': 'CS202210140_312'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_311_13',
#   'cell_set_accession': 'CS202210140_507',
#   'parent_cell_set_accession': 'CS202210140_312'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_310_14',
#   'cell_set_accession': 'CS202210140_508',
#   'parent_cell_set_accession': 'CS202210140_311'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_310_15',
#   'cell_set_accession': 'CS202210140_509',
#   'parent_cell_set_accession': 'CS202210140_311'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_312_16',
#   'cell_set_accession': 'CS202210140_510',
#   'parent_cell_set_accession': 'CS202210140_313'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_312_17',
#   'cell_set_accession': 'CS202210140_511',
#   'parent_cell_set_accession': 'CS202210140_313'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_312_18',
#   'cell_set_accession': 'CS202210140_512',
#   'parent_cell_set_accession': 'CS202210140_313'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_312_19',
#   'cell_set_accession': 'CS202210140_513',
#   'parent_cell_set_accession': 'CS202210140_313'},
#  {'labelset': 'subcluster',
#   'cell_label': 'URL_312_20',
#   'cell_set_accession': 'CS202210140_514',
#   'parent_cell_set_accession': 'CS202210140_313'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Misc_314_21',
#   'cell_set_accession': 'CS202210140_515',
#   'parent_cell_set_accession': 'CS202210140_315'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_363_22',
#   'cell_set_accession': 'CS202210140_516',
#   'parent_cell_set_accession': 'CS202210140_364'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_363_23',
#   'cell_set_accession': 'CS202210140_517',
#   'parent_cell_set_accession': 'CS202210140_364'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_363_24',
#   'cell_set_accession': 'CS202210140_518',
#   'parent_cell_set_accession': 'CS202210140_364'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_363_25',
#   'cell_set_accession': 'CS202210140_519',
#   'parent_cell_set_accession': 'CS202210140_364'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_363_26',
#   'cell_set_accession': 'CS202210140_520',
#   'parent_cell_set_accession': 'CS202210140_364'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_341_27',
#   'cell_set_accession': 'CS202210140_521',
#   'parent_cell_set_accession': 'CS202210140_342'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_28',
#   'cell_set_accession': 'CS202210140_522',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_29',
#   'cell_set_accession': 'CS202210140_523',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_30',
#   'cell_set_accession': 'CS202210140_524',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_31',
#   'cell_set_accession': 'CS202210140_525',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_32',
#   'cell_set_accession': 'CS202210140_526',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_342_33',
#   'cell_set_accession': 'CS202210140_527',
#   'parent_cell_set_accession': 'CS202210140_343'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_336_34',
#   'cell_set_accession': 'CS202210140_528',
#   'parent_cell_set_accession': 'CS202210140_337'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_338_35',
#   'cell_set_accession': 'CS202210140_529',
#   'parent_cell_set_accession': 'CS202210140_339'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_338_36',
#   'cell_set_accession': 'CS202210140_530',
#   'parent_cell_set_accession': 'CS202210140_339'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_338_37',
#   'cell_set_accession': 'CS202210140_531',
#   'parent_cell_set_accession': 'CS202210140_339'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_338_38',
#   'cell_set_accession': 'CS202210140_532',
#   'parent_cell_set_accession': 'CS202210140_339'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_339_39',
#   'cell_set_accession': 'CS202210140_533',
#   'parent_cell_set_accession': 'CS202210140_340'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_339_40',
#   'cell_set_accession': 'CS202210140_534',
#   'parent_cell_set_accession': 'CS202210140_340'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_460_41',
#   'cell_set_accession': 'CS202210140_535',
#   'parent_cell_set_accession': 'CS202210140_461'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_460_42',
#   'cell_set_accession': 'CS202210140_536',
#   'parent_cell_set_accession': 'CS202210140_461'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_460_43',
#   'cell_set_accession': 'CS202210140_537',
#   'parent_cell_set_accession': 'CS202210140_461'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_459_44',
#   'cell_set_accession': 'CS202210140_538',
#   'parent_cell_set_accession': 'CS202210140_460'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_459_45',
#   'cell_set_accession': 'CS202210140_539',
#   'parent_cell_set_accession': 'CS202210140_460'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_46',
#   'cell_set_accession': 'CS202210140_540',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_459_47',
#   'cell_set_accession': 'CS202210140_541',
#   'parent_cell_set_accession': 'CS202210140_460'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_48',
#   'cell_set_accession': 'CS202210140_542',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_49',
#   'cell_set_accession': 'CS202210140_543',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_50',
#   'cell_set_accession': 'CS202210140_544',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_51',
#   'cell_set_accession': 'CS202210140_545',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_52',
#   'cell_set_accession': 'CS202210140_546',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_53',
#   'cell_set_accession': 'CS202210140_547',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_455_54',
#   'cell_set_accession': 'CS202210140_548',
#   'parent_cell_set_accession': 'CS202210140_456'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_460_55',
#   'cell_set_accession': 'CS202210140_549',
#   'parent_cell_set_accession': 'CS202210140_461'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_460_56',
#   'cell_set_accession': 'CS202210140_550',
#   'parent_cell_set_accession': 'CS202210140_461'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_457_57',
#   'cell_set_accession': 'CS202210140_551',
#   'parent_cell_set_accession': 'CS202210140_458'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_457_58',
#   'cell_set_accession': 'CS202210140_552',
#   'parent_cell_set_accession': 'CS202210140_458'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_457_59',
#   'cell_set_accession': 'CS202210140_553',
#   'parent_cell_set_accession': 'CS202210140_458'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_457_60',
#   'cell_set_accession': 'CS202210140_554',
#   'parent_cell_set_accession': 'CS202210140_458'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_457_61',
#   'cell_set_accession': 'CS202210140_555',
#   'parent_cell_set_accession': 'CS202210140_458'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_449_62',
#   'cell_set_accession': 'CS202210140_556',
#   'parent_cell_set_accession': 'CS202210140_450'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_449_63',
#   'cell_set_accession': 'CS202210140_557',
#   'parent_cell_set_accession': 'CS202210140_450'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_64',
#   'cell_set_accession': 'CS202210140_558',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_65',
#   'cell_set_accession': 'CS202210140_559',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_66',
#   'cell_set_accession': 'CS202210140_560',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_67',
#   'cell_set_accession': 'CS202210140_561',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_68',
#   'cell_set_accession': 'CS202210140_562',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_69',
#   'cell_set_accession': 'CS202210140_563',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_70',
#   'cell_set_accession': 'CS202210140_564',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_71',
#   'cell_set_accession': 'CS202210140_565',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_72',
#   'cell_set_accession': 'CS202210140_566',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_73',
#   'cell_set_accession': 'CS202210140_567',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_74',
#   'cell_set_accession': 'CS202210140_568',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_75',
#   'cell_set_accession': 'CS202210140_569',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_456_76',
#   'cell_set_accession': 'CS202210140_570',
#   'parent_cell_set_accession': 'CS202210140_457'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_77',
#   'cell_set_accession': 'CS202210140_571',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_78',
#   'cell_set_accession': 'CS202210140_572',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_79',
#   'cell_set_accession': 'CS202210140_573',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_454_80',
#   'cell_set_accession': 'CS202210140_574',
#   'parent_cell_set_accession': 'CS202210140_455'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_454_81',
#   'cell_set_accession': 'CS202210140_575',
#   'parent_cell_set_accession': 'CS202210140_455'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_454_82',
#   'cell_set_accession': 'CS202210140_576',
#   'parent_cell_set_accession': 'CS202210140_455'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_83',
#   'cell_set_accession': 'CS202210140_577',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_84',
#   'cell_set_accession': 'CS202210140_578',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_85',
#   'cell_set_accession': 'CS202210140_579',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_86',
#   'cell_set_accession': 'CS202210140_580',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_87',
#   'cell_set_accession': 'CS202210140_581',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_88',
#   'cell_set_accession': 'CS202210140_582',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_89',
#   'cell_set_accession': 'CS202210140_583',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_451_90',
#   'cell_set_accession': 'CS202210140_584',
#   'parent_cell_set_accession': 'CS202210140_452'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_91',
#   'cell_set_accession': 'CS202210140_585',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_458_92',
#   'cell_set_accession': 'CS202210140_586',
#   'parent_cell_set_accession': 'CS202210140_459'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_93',
#   'cell_set_accession': 'CS202210140_587',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_94',
#   'cell_set_accession': 'CS202210140_588',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_449_95',
#   'cell_set_accession': 'CS202210140_589',
#   'parent_cell_set_accession': 'CS202210140_450'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_96',
#   'cell_set_accession': 'CS202210140_590',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_453_97',
#   'cell_set_accession': 'CS202210140_591',
#   'parent_cell_set_accession': 'CS202210140_454'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_98',
#   'cell_set_accession': 'CS202210140_592',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_454_99',
#   'cell_set_accession': 'CS202210140_593',
#   'parent_cell_set_accession': 'CS202210140_455'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_454_100',
#   'cell_set_accession': 'CS202210140_594',
#   'parent_cell_set_accession': 'CS202210140_455'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_101',
#   'cell_set_accession': 'CS202210140_595',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_102',
#   'cell_set_accession': 'CS202210140_596',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_103',
#   'cell_set_accession': 'CS202210140_597',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_450_104',
#   'cell_set_accession': 'CS202210140_598',
#   'parent_cell_set_accession': 'CS202210140_451'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_449_105',
#   'cell_set_accession': 'CS202210140_599',
#   'parent_cell_set_accession': 'CS202210140_450'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_449_106',
#   'cell_set_accession': 'CS202210140_600',
#   'parent_cell_set_accession': 'CS202210140_450'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_452_107',
#   'cell_set_accession': 'CS202210140_601',
#   'parent_cell_set_accession': 'CS202210140_453'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_452_108',
#   'cell_set_accession': 'CS202210140_602',
#   'parent_cell_set_accession': 'CS202210140_453'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_452_109',
#   'cell_set_accession': 'CS202210140_603',
#   'parent_cell_set_accession': 'CS202210140_453'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_110',
#   'cell_set_accession': 'CS202210140_604',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_111',
#   'cell_set_accession': 'CS202210140_605',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_112',
#   'cell_set_accession': 'CS202210140_606',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_113',
#   'cell_set_accession': 'CS202210140_607',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_114',
#   'cell_set_accession': 'CS202210140_608',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_115',
#   'cell_set_accession': 'CS202210140_609',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_448_116',
#   'cell_set_accession': 'CS202210140_610',
#   'parent_cell_set_accession': 'CS202210140_449'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_117',
#   'cell_set_accession': 'CS202210140_611',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_118',
#   'cell_set_accession': 'CS202210140_612',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_119',
#   'cell_set_accession': 'CS202210140_613',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_120',
#   'cell_set_accession': 'CS202210140_614',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_447_121',
#   'cell_set_accession': 'CS202210140_615',
#   'parent_cell_set_accession': 'CS202210140_448'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_445_122',
#   'cell_set_accession': 'CS202210140_616',
#   'parent_cell_set_accession': 'CS202210140_446'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_446_123',
#   'cell_set_accession': 'CS202210140_617',
#   'parent_cell_set_accession': 'CS202210140_447'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_446_124',
#   'cell_set_accession': 'CS202210140_618',
#   'parent_cell_set_accession': 'CS202210140_447'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_302_125',
#   'cell_set_accession': 'CS202210140_619',
#   'parent_cell_set_accession': 'CS202210140_303'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_298_126',
#   'cell_set_accession': 'CS202210140_620',
#   'parent_cell_set_accession': 'CS202210140_299'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_298_127',
#   'cell_set_accession': 'CS202210140_621',
#   'parent_cell_set_accession': 'CS202210140_299'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_298_128',
#   'cell_set_accession': 'CS202210140_622',
#   'parent_cell_set_accession': 'CS202210140_299'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_301_129',
#   'cell_set_accession': 'CS202210140_623',
#   'parent_cell_set_accession': 'CS202210140_302'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_130',
#   'cell_set_accession': 'CS202210140_624',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_131',
#   'cell_set_accession': 'CS202210140_625',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_132',
#   'cell_set_accession': 'CS202210140_626',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_133',
#   'cell_set_accession': 'CS202210140_627',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_134',
#   'cell_set_accession': 'CS202210140_628',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_299_135',
#   'cell_set_accession': 'CS202210140_629',
#   'parent_cell_set_accession': 'CS202210140_300'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_136',
#   'cell_set_accession': 'CS202210140_630',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_137',
#   'cell_set_accession': 'CS202210140_631',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_138',
#   'cell_set_accession': 'CS202210140_632',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_139',
#   'cell_set_accession': 'CS202210140_633',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_140',
#   'cell_set_accession': 'CS202210140_634',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_141',
#   'cell_set_accession': 'CS202210140_635',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_142',
#   'cell_set_accession': 'CS202210140_636',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_300_143',
#   'cell_set_accession': 'CS202210140_637',
#   'parent_cell_set_accession': 'CS202210140_301'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_303_144',
#   'cell_set_accession': 'CS202210140_638',
#   'parent_cell_set_accession': 'CS202210140_304'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_303_145',
#   'cell_set_accession': 'CS202210140_639',
#   'parent_cell_set_accession': 'CS202210140_304'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_303_146',
#   'cell_set_accession': 'CS202210140_640',
#   'parent_cell_set_accession': 'CS202210140_304'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_303_147',
#   'cell_set_accession': 'CS202210140_641',
#   'parent_cell_set_accession': 'CS202210140_304'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_303_148',
#   'cell_set_accession': 'CS202210140_642',
#   'parent_cell_set_accession': 'CS202210140_304'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_304_149',
#   'cell_set_accession': 'CS202210140_643',
#   'parent_cell_set_accession': 'CS202210140_305'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_304_150',
#   'cell_set_accession': 'CS202210140_644',
#   'parent_cell_set_accession': 'CS202210140_305'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_304_151',
#   'cell_set_accession': 'CS202210140_645',
#   'parent_cell_set_accession': 'CS202210140_305'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_304_152',
#   'cell_set_accession': 'CS202210140_646',
#   'parent_cell_set_accession': 'CS202210140_305'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_306_153',
#   'cell_set_accession': 'CS202210140_647',
#   'parent_cell_set_accession': 'CS202210140_307'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_306_154',
#   'cell_set_accession': 'CS202210140_648',
#   'parent_cell_set_accession': 'CS202210140_307'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_305_155',
#   'cell_set_accession': 'CS202210140_649',
#   'parent_cell_set_accession': 'CS202210140_306'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_305_156',
#   'cell_set_accession': 'CS202210140_650',
#   'parent_cell_set_accession': 'CS202210140_306'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_307_157',
#   'cell_set_accession': 'CS202210140_651',
#   'parent_cell_set_accession': 'CS202210140_308'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_307_158',
#   'cell_set_accession': 'CS202210140_652',
#   'parent_cell_set_accession': 'CS202210140_308'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_307_159',
#   'cell_set_accession': 'CS202210140_653',
#   'parent_cell_set_accession': 'CS202210140_308'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_307_160',
#   'cell_set_accession': 'CS202210140_654',
#   'parent_cell_set_accession': 'CS202210140_308'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_301_161',
#   'cell_set_accession': 'CS202210140_655',
#   'parent_cell_set_accession': 'CS202210140_302'},
#  {'labelset': 'subcluster',
#   'cell_label': 'CBI_301_162',
#   'cell_set_accession': 'CS202210140_656',
#   'parent_cell_set_accession': 'CS202210140_302'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_409_163',
#   'cell_set_accession': 'CS202210140_657',
#   'parent_cell_set_accession': 'CS202210140_410'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_409_164',
#   'cell_set_accession': 'CS202210140_658',
#   'parent_cell_set_accession': 'CS202210140_410'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_409_165',
#   'cell_set_accession': 'CS202210140_659',
#   'parent_cell_set_accession': 'CS202210140_410'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_409_166',
#   'cell_set_accession': 'CS202210140_660',
#   'parent_cell_set_accession': 'CS202210140_410'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_409_167',
#   'cell_set_accession': 'CS202210140_661',
#   'parent_cell_set_accession': 'CS202210140_410'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_168',
#   'cell_set_accession': 'CS202210140_662',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_169',
#   'cell_set_accession': 'CS202210140_663',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_170',
#   'cell_set_accession': 'CS202210140_664',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_171',
#   'cell_set_accession': 'CS202210140_665',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_172',
#   'cell_set_accession': 'CS202210140_666',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_173',
#   'cell_set_accession': 'CS202210140_667',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_174',
#   'cell_set_accession': 'CS202210140_668',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_175',
#   'cell_set_accession': 'CS202210140_669',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_176',
#   'cell_set_accession': 'CS202210140_670',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_177',
#   'cell_set_accession': 'CS202210140_671',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_238_178',
#   'cell_set_accession': 'CS202210140_672',
#   'parent_cell_set_accession': 'CS202210140_239'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_179',
#   'cell_set_accession': 'CS202210140_673',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_180',
#   'cell_set_accession': 'CS202210140_674',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_181',
#   'cell_set_accession': 'CS202210140_675',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_182',
#   'cell_set_accession': 'CS202210140_676',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_183',
#   'cell_set_accession': 'CS202210140_677',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_184',
#   'cell_set_accession': 'CS202210140_678',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_237_185',
#   'cell_set_accession': 'CS202210140_679',
#   'parent_cell_set_accession': 'CS202210140_238'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_425_186',
#   'cell_set_accession': 'CS202210140_680',
#   'parent_cell_set_accession': 'CS202210140_426'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_187',
#   'cell_set_accession': 'CS202210140_681',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_188',
#   'cell_set_accession': 'CS202210140_682',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_189',
#   'cell_set_accession': 'CS202210140_683',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_190',
#   'cell_set_accession': 'CS202210140_684',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_191',
#   'cell_set_accession': 'CS202210140_685',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_192',
#   'cell_set_accession': 'CS202210140_686',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_193',
#   'cell_set_accession': 'CS202210140_687',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_194',
#   'cell_set_accession': 'CS202210140_688',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_195',
#   'cell_set_accession': 'CS202210140_689',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_196',
#   'cell_set_accession': 'CS202210140_690',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_197',
#   'cell_set_accession': 'CS202210140_691',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_198',
#   'cell_set_accession': 'CS202210140_692',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_199',
#   'cell_set_accession': 'CS202210140_693',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_200',
#   'cell_set_accession': 'CS202210140_694',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_201',
#   'cell_set_accession': 'CS202210140_695',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_202',
#   'cell_set_accession': 'CS202210140_696',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_203',
#   'cell_set_accession': 'CS202210140_697',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_204',
#   'cell_set_accession': 'CS202210140_698',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_205',
#   'cell_set_accession': 'CS202210140_699',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_206',
#   'cell_set_accession': 'CS202210140_700',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_207',
#   'cell_set_accession': 'CS202210140_701',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_208',
#   'cell_set_accession': 'CS202210140_702',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_209',
#   'cell_set_accession': 'CS202210140_703',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_210',
#   'cell_set_accession': 'CS202210140_704',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_211',
#   'cell_set_accession': 'CS202210140_705',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_212',
#   'cell_set_accession': 'CS202210140_706',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_213',
#   'cell_set_accession': 'CS202210140_707',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_214',
#   'cell_set_accession': 'CS202210140_708',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_215',
#   'cell_set_accession': 'CS202210140_709',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_216',
#   'cell_set_accession': 'CS202210140_710',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_217',
#   'cell_set_accession': 'CS202210140_711',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_218',
#   'cell_set_accession': 'CS202210140_712',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_253_219',
#   'cell_set_accession': 'CS202210140_713',
#   'parent_cell_set_accession': 'CS202210140_254'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_254_220',
#   'cell_set_accession': 'CS202210140_714',
#   'parent_cell_set_accession': 'CS202210140_255'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_221',
#   'cell_set_accession': 'CS202210140_715',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_222',
#   'cell_set_accession': 'CS202210140_716',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_223',
#   'cell_set_accession': 'CS202210140_717',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_224',
#   'cell_set_accession': 'CS202210140_718',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_225',
#   'cell_set_accession': 'CS202210140_719',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_226',
#   'cell_set_accession': 'CS202210140_720',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_227',
#   'cell_set_accession': 'CS202210140_721',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_228',
#   'cell_set_accession': 'CS202210140_722',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_229',
#   'cell_set_accession': 'CS202210140_723',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_230',
#   'cell_set_accession': 'CS202210140_724',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_231',
#   'cell_set_accession': 'CS202210140_725',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_232',
#   'cell_set_accession': 'CS202210140_726',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_233',
#   'cell_set_accession': 'CS202210140_727',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_234',
#   'cell_set_accession': 'CS202210140_728',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_235',
#   'cell_set_accession': 'CS202210140_729',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_236',
#   'cell_set_accession': 'CS202210140_730',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_237',
#   'cell_set_accession': 'CS202210140_731',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_238',
#   'cell_set_accession': 'CS202210140_732',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_246_239',
#   'cell_set_accession': 'CS202210140_733',
#   'parent_cell_set_accession': 'CS202210140_247'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_240',
#   'cell_set_accession': 'CS202210140_734',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_241',
#   'cell_set_accession': 'CS202210140_735',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_242',
#   'cell_set_accession': 'CS202210140_736',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_243',
#   'cell_set_accession': 'CS202210140_737',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_244',
#   'cell_set_accession': 'CS202210140_738',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_245',
#   'cell_set_accession': 'CS202210140_739',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_247_246',
#   'cell_set_accession': 'CS202210140_740',
#   'parent_cell_set_accession': 'CS202210140_248'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_247',
#   'cell_set_accession': 'CS202210140_741',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_248',
#   'cell_set_accession': 'CS202210140_742',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_249',
#   'cell_set_accession': 'CS202210140_743',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_250',
#   'cell_set_accession': 'CS202210140_744',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_251',
#   'cell_set_accession': 'CS202210140_745',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_252',
#   'cell_set_accession': 'CS202210140_746',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_253',
#   'cell_set_accession': 'CS202210140_747',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_254',
#   'cell_set_accession': 'CS202210140_748',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_255',
#   'cell_set_accession': 'CS202210140_749',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_256',
#   'cell_set_accession': 'CS202210140_750',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_252_257',
#   'cell_set_accession': 'CS202210140_751',
#   'parent_cell_set_accession': 'CS202210140_253'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_258',
#   'cell_set_accession': 'CS202210140_752',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_259',
#   'cell_set_accession': 'CS202210140_753',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_260',
#   'cell_set_accession': 'CS202210140_754',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_261',
#   'cell_set_accession': 'CS202210140_755',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_262',
#   'cell_set_accession': 'CS202210140_756',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_263',
#   'cell_set_accession': 'CS202210140_757',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_264',
#   'cell_set_accession': 'CS202210140_758',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_265',
#   'cell_set_accession': 'CS202210140_759',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_266',
#   'cell_set_accession': 'CS202210140_760',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_249_267',
#   'cell_set_accession': 'CS202210140_761',
#   'parent_cell_set_accession': 'CS202210140_250'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_268',
#   'cell_set_accession': 'CS202210140_762',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_269',
#   'cell_set_accession': 'CS202210140_763',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_270',
#   'cell_set_accession': 'CS202210140_764',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_271',
#   'cell_set_accession': 'CS202210140_765',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_272',
#   'cell_set_accession': 'CS202210140_766',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_273',
#   'cell_set_accession': 'CS202210140_767',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_274',
#   'cell_set_accession': 'CS202210140_768',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_275',
#   'cell_set_accession': 'CS202210140_769',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_276',
#   'cell_set_accession': 'CS202210140_770',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_277',
#   'cell_set_accession': 'CS202210140_771',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_278',
#   'cell_set_accession': 'CS202210140_772',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_279',
#   'cell_set_accession': 'CS202210140_773',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_280',
#   'cell_set_accession': 'CS202210140_774',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_281',
#   'cell_set_accession': 'CS202210140_775',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_282',
#   'cell_set_accession': 'CS202210140_776',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_250_283',
#   'cell_set_accession': 'CS202210140_777',
#   'parent_cell_set_accession': 'CS202210140_251'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_251_284',
#   'cell_set_accession': 'CS202210140_778',
#   'parent_cell_set_accession': 'CS202210140_252'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_248_285',
#   'cell_set_accession': 'CS202210140_779',
#   'parent_cell_set_accession': 'CS202210140_249'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_286',
#   'cell_set_accession': 'CS202210140_780',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_287',
#   'cell_set_accession': 'CS202210140_781',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_288',
#   'cell_set_accession': 'CS202210140_782',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_289',
#   'cell_set_accession': 'CS202210140_783',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_290',
#   'cell_set_accession': 'CS202210140_784',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_291',
#   'cell_set_accession': 'CS202210140_785',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_244_292',
#   'cell_set_accession': 'CS202210140_786',
#   'parent_cell_set_accession': 'CS202210140_245'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_235_293',
#   'cell_set_accession': 'CS202210140_787',
#   'parent_cell_set_accession': 'CS202210140_236'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_294',
#   'cell_set_accession': 'CS202210140_788',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_295',
#   'cell_set_accession': 'CS202210140_789',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_296',
#   'cell_set_accession': 'CS202210140_790',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_297',
#   'cell_set_accession': 'CS202210140_791',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_245_298',
#   'cell_set_accession': 'CS202210140_792',
#   'parent_cell_set_accession': 'CS202210140_246'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_299',
#   'cell_set_accession': 'CS202210140_793',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_300',
#   'cell_set_accession': 'CS202210140_794',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_301',
#   'cell_set_accession': 'CS202210140_795',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_302',
#   'cell_set_accession': 'CS202210140_796',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_303',
#   'cell_set_accession': 'CS202210140_797',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_304',
#   'cell_set_accession': 'CS202210140_798',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_305',
#   'cell_set_accession': 'CS202210140_799',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_306',
#   'cell_set_accession': 'CS202210140_800',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_243_307',
#   'cell_set_accession': 'CS202210140_801',
#   'parent_cell_set_accession': 'CS202210140_244'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_308',
#   'cell_set_accession': 'CS202210140_802',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_309',
#   'cell_set_accession': 'CS202210140_803',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_310',
#   'cell_set_accession': 'CS202210140_804',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_311',
#   'cell_set_accession': 'CS202210140_805',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
#   'cell_label': 'MGE_242_312',
#   'cell_set_accession': 'CS202210140_806',
#   'parent_cell_set_accession': 'CS202210140_243'},
#  {'labelset': 'subcluster',
# ...
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_898',
#   'cell_set_accession': 'CS202210140_1392',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_899',
#   'cell_set_accession': 'CS202210140_1393',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_900',
#   'cell_set_accession': 'CS202210140_1394',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_901',
#   'cell_set_accession': 'CS202210140_1395',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_902',
#   'cell_set_accession': 'CS202210140_1396',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_903',
#   'cell_set_accession': 'CS202210140_1397',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_904',
#   'cell_set_accession': 'CS202210140_1398',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_905',
#   'cell_set_accession': 'CS202210140_1399',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_906',
#   'cell_set_accession': 'CS202210140_1400',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_907',
#   'cell_set_accession': 'CS202210140_1401',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_908',
#   'cell_set_accession': 'CS202210140_1402',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_909',
#   'cell_set_accession': 'CS202210140_1403',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_910',
#   'cell_set_accession': 'CS202210140_1404',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_911',
#   'cell_set_accession': 'CS202210140_1405',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_912',
#   'cell_set_accession': 'CS202210140_1406',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_349_913',
#   'cell_set_accession': 'CS202210140_1407',
#   'parent_cell_set_accession': 'CS202210140_350'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_347_914',
#   'cell_set_accession': 'CS202210140_1408',
#   'parent_cell_set_accession': 'CS202210140_348'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_347_915',
#   'cell_set_accession': 'CS202210140_1409',
#   'parent_cell_set_accession': 'CS202210140_348'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_381_916',
#   'cell_set_accession': 'CS202210140_1410',
#   'parent_cell_set_accession': 'CS202210140_382'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_381_917',
#   'cell_set_accession': 'CS202210140_1411',
#   'parent_cell_set_accession': 'CS202210140_382'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_381_918',
#   'cell_set_accession': 'CS202210140_1412',
#   'parent_cell_set_accession': 'CS202210140_382'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_919',
#   'cell_set_accession': 'CS202210140_1413',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_920',
#   'cell_set_accession': 'CS202210140_1414',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_921',
#   'cell_set_accession': 'CS202210140_1415',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_922',
#   'cell_set_accession': 'CS202210140_1416',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_923',
#   'cell_set_accession': 'CS202210140_1417',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_924',
#   'cell_set_accession': 'CS202210140_1418',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_925',
#   'cell_set_accession': 'CS202210140_1419',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_926',
#   'cell_set_accession': 'CS202210140_1420',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_927',
#   'cell_set_accession': 'CS202210140_1421',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_374_928',
#   'cell_set_accession': 'CS202210140_1422',
#   'parent_cell_set_accession': 'CS202210140_375'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_378_929',
#   'cell_set_accession': 'CS202210140_1423',
#   'parent_cell_set_accession': 'CS202210140_379'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_378_930',
#   'cell_set_accession': 'CS202210140_1424',
#   'parent_cell_set_accession': 'CS202210140_379'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_378_931',
#   'cell_set_accession': 'CS202210140_1425',
#   'parent_cell_set_accession': 'CS202210140_379'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_386_932',
#   'cell_set_accession': 'CS202210140_1426',
#   'parent_cell_set_accession': 'CS202210140_387'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_386_933',
#   'cell_set_accession': 'CS202210140_1427',
#   'parent_cell_set_accession': 'CS202210140_387'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_386_934',
#   'cell_set_accession': 'CS202210140_1428',
#   'parent_cell_set_accession': 'CS202210140_387'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_386_935',
#   'cell_set_accession': 'CS202210140_1429',
#   'parent_cell_set_accession': 'CS202210140_387'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_936',
#   'cell_set_accession': 'CS202210140_1430',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_937',
#   'cell_set_accession': 'CS202210140_1431',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_938',
#   'cell_set_accession': 'CS202210140_1432',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_939',
#   'cell_set_accession': 'CS202210140_1433',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Amex_407_940',
#   'cell_set_accession': 'CS202210140_1434',
#   'parent_cell_set_accession': 'CS202210140_408'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Amex_407_941',
#   'cell_set_accession': 'CS202210140_1435',
#   'parent_cell_set_accession': 'CS202210140_408'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Amex_407_942',
#   'cell_set_accession': 'CS202210140_1436',
#   'parent_cell_set_accession': 'CS202210140_408'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Amex_407_943',
#   'cell_set_accession': 'CS202210140_1437',
#   'parent_cell_set_accession': 'CS202210140_408'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_944',
#   'cell_set_accession': 'CS202210140_1438',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_945',
#   'cell_set_accession': 'CS202210140_1439',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_946',
#   'cell_set_accession': 'CS202210140_1440',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_947',
#   'cell_set_accession': 'CS202210140_1441',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_948',
#   'cell_set_accession': 'CS202210140_1442',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_379_949',
#   'cell_set_accession': 'CS202210140_1443',
#   'parent_cell_set_accession': 'CS202210140_380'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_379_950',
#   'cell_set_accession': 'CS202210140_1444',
#   'parent_cell_set_accession': 'CS202210140_380'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_951',
#   'cell_set_accession': 'CS202210140_1445',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_952',
#   'cell_set_accession': 'CS202210140_1446',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_953',
#   'cell_set_accession': 'CS202210140_1447',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_954',
#   'cell_set_accession': 'CS202210140_1448',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_955',
#   'cell_set_accession': 'CS202210140_1449',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_366_956',
#   'cell_set_accession': 'CS202210140_1450',
#   'parent_cell_set_accession': 'CS202210140_367'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_957',
#   'cell_set_accession': 'CS202210140_1451',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_958',
#   'cell_set_accession': 'CS202210140_1452',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_959',
#   'cell_set_accession': 'CS202210140_1453',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_960',
#   'cell_set_accession': 'CS202210140_1454',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_380_961',
#   'cell_set_accession': 'CS202210140_1455',
#   'parent_cell_set_accession': 'CS202210140_381'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_396_962',
#   'cell_set_accession': 'CS202210140_1456',
#   'parent_cell_set_accession': 'CS202210140_397'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_963',
#   'cell_set_accession': 'CS202210140_1457',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_343_964',
#   'cell_set_accession': 'CS202210140_1458',
#   'parent_cell_set_accession': 'CS202210140_344'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_398_965',
#   'cell_set_accession': 'CS202210140_1459',
#   'parent_cell_set_accession': 'CS202210140_399'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_966',
#   'cell_set_accession': 'CS202210140_1460',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_967',
#   'cell_set_accession': 'CS202210140_1461',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_968',
#   'cell_set_accession': 'CS202210140_1462',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_969',
#   'cell_set_accession': 'CS202210140_1463',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_970',
#   'cell_set_accession': 'CS202210140_1464',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_387_971',
#   'cell_set_accession': 'CS202210140_1465',
#   'parent_cell_set_accession': 'CS202210140_388'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_339_972',
#   'cell_set_accession': 'CS202210140_1466',
#   'parent_cell_set_accession': 'CS202210140_340'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_339_973',
#   'cell_set_accession': 'CS202210140_1467',
#   'parent_cell_set_accession': 'CS202210140_340'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_388_974',
#   'cell_set_accession': 'CS202210140_1468',
#   'parent_cell_set_accession': 'CS202210140_389'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_388_975',
#   'cell_set_accession': 'CS202210140_1469',
#   'parent_cell_set_accession': 'CS202210140_389'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_388_976',
#   'cell_set_accession': 'CS202210140_1470',
#   'parent_cell_set_accession': 'CS202210140_389'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_388_977',
#   'cell_set_accession': 'CS202210140_1471',
#   'parent_cell_set_accession': 'CS202210140_389'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_978',
#   'cell_set_accession': 'CS202210140_1472',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_979',
#   'cell_set_accession': 'CS202210140_1473',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_980',
#   'cell_set_accession': 'CS202210140_1474',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_981',
#   'cell_set_accession': 'CS202210140_1475',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_982',
#   'cell_set_accession': 'CS202210140_1476',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_983',
#   'cell_set_accession': 'CS202210140_1477',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_984',
#   'cell_set_accession': 'CS202210140_1478',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_985',
#   'cell_set_accession': 'CS202210140_1479',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_986',
#   'cell_set_accession': 'CS202210140_1480',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_372_987',
#   'cell_set_accession': 'CS202210140_1481',
#   'parent_cell_set_accession': 'CS202210140_373'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_372_988',
#   'cell_set_accession': 'CS202210140_1482',
#   'parent_cell_set_accession': 'CS202210140_373'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Thex_372_989',
#   'cell_set_accession': 'CS202210140_1483',
#   'parent_cell_set_accession': 'CS202210140_373'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_990',
#   'cell_set_accession': 'CS202210140_1484',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_991',
#   'cell_set_accession': 'CS202210140_1485',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_373_992',
#   'cell_set_accession': 'CS202210140_1486',
#   'parent_cell_set_accession': 'CS202210140_374'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_993',
#   'cell_set_accession': 'CS202210140_1487',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_344_994',
#   'cell_set_accession': 'CS202210140_1488',
#   'parent_cell_set_accession': 'CS202210140_345'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_367_995',
#   'cell_set_accession': 'CS202210140_1489',
#   'parent_cell_set_accession': 'CS202210140_368'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_367_996',
#   'cell_set_accession': 'CS202210140_1490',
#   'parent_cell_set_accession': 'CS202210140_368'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_367_997',
#   'cell_set_accession': 'CS202210140_1491',
#   'parent_cell_set_accession': 'CS202210140_368'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_367_998',
#   'cell_set_accession': 'CS202210140_1492',
#   'parent_cell_set_accession': 'CS202210140_368'},
#  {'labelset': 'subcluster',
#   'cell_label': 'Splat_367_999',
#   'cell_set_accession': 'CS202210140_1493',
#   'parent_cell_set_accession': 'CS202210140_368'},
#  ...]

# %%
import re
# Testing regex pattern
m = re.match('.+_(\d+)', 'URL_297_0')
m.group(1)
# Out:
# '0'

# %%
# Use regex matching ID -> label to attach cell_ids to subclusters
for c in neuron_subclusters:
    m = re.match('.+_(\d+)', c['cell_label'])
    if int(m.group(1)) in subcluster_cell_id_lookup.keys():
        c['cell_ids'] = subcluster_cell_id_lookup[int(m.group(1))]

# %%
# Test addition cell_Ids has worked
neuron_subclusters[0]['cell_ids'][0:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Test addition cell_Ids has worked
# ----> 2 neuron_subclusters[0]['cell_id'][0:5]
#
# KeyError: 'cell_id'

# %%
import pandas as pd
AT = pd.read_csv('./Annotation_transfer/Clusters_AT_from_MTG.tsv', sep='\t')
MTG_annotations = pd.read_csv('./MTG_cas/CCN20240304_annotations.tsv', sep='\t')
MTG_annotations[0:5]
# Out:
#   cell_set_accession cell_label cell_fullname parent_cell_set_accession  \
# 0         b15b444731      Vip_2         Vip_2                082c817b6f
# 1         83796aa6d9     Sst_11        Sst_11                8fa477a378
# 2         8c25f3eded     Sst_31        Sst_31                8fa477a378
# 3         319ad7ab6a     Sst_37        Sst_37                8fa477a378
# 4         51b6c3ddc3    L6 CT_3       L6 CT_3                d4ee4a2c4c
#
#   parent_cell_set_name           labelset cell_ontology_term_id  \
# 0                  Vip  CrossArea_cluster            CL:4023016
# 1                  Sst  CrossArea_cluster            CL:4023017
# 2                  Sst  CrossArea_cluster            CL:4023017
# 3                  Sst  CrossArea_cluster            CL:4023017
# 4                L6 CT  CrossArea_cluster            CL:4023013
#
#                                   cell_ontology_term  rationale  \
# 0                 vip GABAergic cortical interneuron        NaN
# 1                 sst GABAergic cortical interneuron        NaN
# 2                 sst GABAergic cortical interneuron        NaN
# 3                 sst GABAergic cortical interneuron        NaN
# 4  corticothalamic-projecting glutamatergic corti...        NaN
#
#    rationale_dois  marker_gene_evidence  synonyms
# 0             NaN                   NaN       NaN
# 1             NaN                   NaN       NaN
# 2             NaN                   NaN       NaN
# 3             NaN                   NaN       NaN
# 4             NaN                   NaN       NaN

# %%
# Aim 
# Look up transfered MTG names (in MT) in MTG cell_label var - MT - & link Siletti Cell label to MTG annotation object

# 1. Make template for annotation transfer objects
# 2. Iterate over annotatoin transfer labels, matching to cluster labels & using this to generate annotation transfer objects.
# 3. Attach annotation transfer objects to annotatinons

# %%
MTG_annotation_lookup = MTG_annotations.set_index("cell_label").to_dict(orient='index')

# %%
# What matches?
set(MTG_annotation_lookup.keys()).intersection(set(AT['Transferred MTG Label']))
# Out:
# {'Astro',
#  'Chandelier',
#  'Endo',
#  'L2/3 IT',
#  'L4 IT',
#  'L5 IT',
#  'L5/6 NP',
#  'L6 CT',
#  'L6 IT',
#  'L6 IT Car3',
#  'L6b',
#  'Lamp5',
#  'Lamp5 Lhx6',
#  'OPC',
#  'Oligo',
#  'Pax6',
#  'Pvalb',
#  'Sncg',
#  'Sst',
#  'VLMC',
#  'Vip'}

# %%
# What doesn't match?  - Can we match this by hand?
(set(AT['Transferred MTG Label']))-set(MTG_annotation_lookup.keys())
# Out:
# {'Micro-PVM', nan}

# %%
# Dict comp => Dict keyed on Siletti Cluster_name (=cell_label) with value = MTG annotation transfer object
# Iterate over Transferred annotations (AT)
out = {}
comment = "We performed PCA (50 components) on our full dataset, trained a random forest classifier (scikit-learn, class_ weight=‘balanced’, max_depth=50) on the MTG labels, and then predicted labels for all cells. We labeled each cluster with the mode of its constituent cells if two conditions were met: more than 0.8 of predicted labels matched the mode, and the mean probability of these pre- dictions was greater than 0.8."
for i,r in AT.iterrows(): 
    if r['Transferred MTG Label'] in MTG_annotation_lookup.keys():
        MTG_ann =  MTG_annotation_lookup[r['Transferred MTG Label']]
        out[r['Cluster name']]= { "transferred_cell_label" : r['Transferred MTG Label'], 
                                  "source_node_accession": MTG_ann['labelset'] + '_' + MTG_ann['cell_set_accession'],
                                  "source_taxonomy": "https://purl.brain-bican.org/taxonomy/AIT_MTG/AIT_MTG.json",
                                  "comment": comment }
# Test
out['Amex_175']
# Out:
# {'transferred_cell_label': 'L2/3 IT',
#  'source_node_accession': 'CrossArea_subclass_58570ade17',
#  'source_taxonomy': 'https://purl.brain-bican.org/taxonomy/AIT_MTG/AIT_MTG.json',
#  'comment': 'We performed PCA (50 components) on our full dataset, trained a random forest classifier (scikit-learn, class_ weight=‘balanced’, max_depth=50) on the MTG labels, and then predicted labels for all cells. We labeled each cluster with the mode of its constituent cells if two conditions were met: more than 0.8 of predicted labels matched the mode, and the mean probability of these pre- dictions was greater than 0.8.'}

# %%
# Attach Annotation transfers to CAS for nn & neurons matching on names

for a in neurons['annotations']:
    if a['cell_label'] in out.keys():
        a['annotation_transfer'] = [out[a['cell_label']]]
        # Testing
[a['annotation_transfer'] for a in neurons['annotations'] if 'annotation_transfer' in a.keys()][0]
# Out:
# [{'transferred_cell_label': 'L5/6 NP',
#   'source_node_accession': 'CrossArea_subclass_2d233a9ab8',
#   'source_taxonomy': 'https://purl.brain-bican.org/taxonomy/AIT_MTG/AIT_MTG.json',
#   'comment': 'We performed PCA (50 components) on our full dataset, trained a random forest classifier (scikit-learn, class_ weight=‘balanced’, max_depth=50) on the MTG labels, and then predicted labels for all cells. We labeled each cluster with the mode of its constituent cells if two conditions were met: more than 0.8 of predicted labels matched the mode, and the mean probability of these pre- dictions was greater than 0.8.'}]

# %%
# TODO - repeat for Neurons. Save and test CAS.json
